# %%
from os.path import join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Data Import
data = pd.read_csv(join('data','fire-incidents.csv'),sep=';')
data.head(5)
# Out:
#                    alarmtime  year incidentnum  exp_no  incidentcode  \
# 0  2020-01-11T19:59:56+00:00  2020  20-0000460       0           NaN
# 1  2020-01-11T19:17:47+00:00  2020  20-0000458       0         611.0
# 2  2020-01-11T14:18:46+00:00  2020  20-0000451       0         322.0
# 3  2020-01-11T14:03:30+00:00  2020  20-0000449       0         551.0
# 4  2020-01-11T12:08:49+00:00  2020  20-0000443       0         321.0
#
#                                        incitypedesc indicentdesc  \
# 0                                               NaN          NaN
# 1                   Dispatched & cancelled en route  GOOD INTENT
# 2              Motor vehicle accident with injuries          EMS
# 3        Assist police or other governmental agency      SERVICE
# 4  EMS call, excluding vehicle accident with injury          EMS
#
#   majorcategory             streetaddress mutl_aid  station shift  \
# 0       UNKNOWN          1001 WINSTEAD DR      NaN        1     C
# ...
